# %%
import os
import shutil
import json
from sklearn.model_selection import train_test_split

def split_dataset_with_annotations(images_dir, annotations_file, output_dir, test_size=0.1, val_size=0.2, seed=42):
    # Create output directories
    for split in ['train', 'val', 'test']:
        os.makedirs(os.path.join(output_dir, split, 'images'), exist_ok=True)

    # Load image files
    image_files = [f for f in os.listdir(images_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    image_files.sort()

    # Load annotations
    with open(annotations_file, 'r') as f:
        annotations = json.load(f)

    # First split: train_val (90%) and test (10%)
    train_val_files, test_files = train_test_split(image_files, test_size=test_size, random_state=seed)

    # Second split: train (70%) and val (20%) from the remaining 90%
    train_files, val_files = train_test_split(train_val_files, test_size=val_size/(1 - test_size), random_state=seed)

    # Convert to sets for faster lookup
    train_set = set(train_files)
    val_set = set(val_files)
    test_set = set(test_files)

    def copy_images(files, split):
        for file in files:
            src_img = os.path.join(images_dir, file)
            dst_img = os.path.join(output_dir, split, 'images', file)
            shutil.copy(src_img, dst_img)

    def save_annotations(filtered_files, split):
        split_annotations = {
            "annotations": [],
            "images": [],
            "categories": annotations.get("categories", [])
        }

        # Filter annotations based on image filenames
        image_id_map = {}
        for img in annotations['images']:
            if img['file_name'] in filtered_files:
                split_annotations['images'].append(img)
                image_id_map[img['id']] = img['file_name']

        for ann in annotations['annotations']:
            if ann['image_id'] in image_id_map:
                split_annotations['annotations'].append(ann)

        # Save split-specific annotations
        out_file = os.path.join(output_dir, split, 'annotations.json')
        with open(out_file, 'w') as f:
            json.dump(split_annotations, f, indent=2)

    # Copy images and save filtered annotations for each split
    copy_images(train_files, 'train')
    save_annotations(train_files, 'train')

    copy_images(val_files, 'val')
    save_annotations(val_files, 'val')

    copy_images(test_files, 'test')
    save_annotations(test_files, 'test')

    # Summary
    print(f'''
✅ Dataset split complete:
- Train: {len(train_files)} images ({len(train_files)/len(image_files):.1%})
- Val: {len(val_files)} images ({len(val_files)/len(image_files):.1%})
- Test: {len(test_files)} images ({len(test_files)/len(image_files):.1%})
Output directory: {output_dir}
''')

# === Run the function with your setup ===

split_dataset_with_annotations(
    images_dir='images',
    annotations_file='annotations.json',
    output_dir='output',
    test_size=0.1,
    val_size=0.2,
    seed=42
)
# Out:
# ✅ Dataset split complete:
# - Train: 98 images (69.0%)
# - Val: 29 images (20.4%)
# - Test: 15 images (10.6%)
# Output directory: output

# %%
import os
import time
import torch
import torchvision
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator
from torchvision.datasets import CocoDetection
from torchvision.transforms import Compose, ToTensor, Resize, RandomHorizontalFlip
from torch.utils.data import DataLoader
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
from torch.cuda.amp import GradScaler

# Dataset Wrapper
class CocoWrapper(CocoDetection):
    def __init__(self, root, annFile, transforms=None):
        super().__init__(root, annFile)
        self._transforms = transforms

    def __getitem__(self, idx):
        image, target = super().__getitem__(idx)
        boxes = []
        labels = []
        for obj in target:
            bbox = obj['bbox']
            bbox = [bbox[0], bbox[1], bbox[0] + bbox[2], bbox[1] + bbox[3]]  # Convert xywh to xyxy
            boxes.append(bbox)
            labels.append(obj['category_id'])

        target = {
            'boxes': torch.tensor(boxes, dtype=torch.float32),
            'labels': torch.tensor(labels, dtype=torch.int64)
        }

        if self._transforms:
            image = self._transforms(image)

        return image, target

# Training Function
def train_model(train_dir, val_dir, num_classes=7, ann_filename='annotations.json', epochs=100, output_dir='results'):
    device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
    print(f"🚀 Using device: {device}")

    os.makedirs(output_dir, exist_ok=True)

    # Transforms
    train_transform = Compose([
        ToTensor(),
        RandomHorizontalFlip(0.5),
        Resize((800, 800)),
    ])
    val_transform = Compose([
        ToTensor(),
        Resize((800, 800)),
    ])

    # Datasets
    train_dataset = CocoWrapper(
        root=os.path.join(train_dir, 'images'),
        annFile=os.path.join(train_dir, ann_filename),
        transforms=train_transform
    )
    val_dataset = CocoWrapper(
        root=os.path.join(val_dir, 'images'),
        annFile=os.path.join(val_dir, ann_filename),
        transforms=val_transform
    )

    # Data Loaders
    train_loader = DataLoader(train_dataset, batch_size=1, shuffle=True, num_workers=2, collate_fn=lambda x: tuple(zip(*x)))
    val_loader = DataLoader(val_dataset, batch_size=1, shuffle=False, num_workers=1, collate_fn=lambda x: tuple(zip(*x)))

    # Model Definition
    backbone = torchvision.models.resnet50(pretrained=True)
    backbone = torch.nn.Sequential(*list(backbone.children())[:-2])
    backbone.out_channels = 2048

    anchor_generator = AnchorGenerator(
        sizes=((32, 64, 128, 256, 512),),
        aspect_ratios=((0.5, 1.0, 2.0),)
    )
    roi_pooler = torchvision.ops.MultiScaleRoIAlign(
        featmap_names=['0'],
        output_size=7,
        sampling_ratio=2
    )

    model = FasterRCNN(
        backbone,
        num_classes=num_classes + 1,
        rpn_anchor_generator=anchor_generator,
        box_roi_pool=roi_pooler
    )
    model.to(device)

    # Training Setup
    params = [p for p in model.parameters() if p.requires_grad]
    optimizer = optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)
    scheduler = lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=15, T_mult=2, eta_min=1e-5)
    scaler = GradScaler()
    best_loss = float('inf')

    # Train Loop
    for epoch in range(epochs):
        model.train()
        total_train_loss = 0.0
        start = time.time()

        for images, targets in train_loader:
            images = [img.to(device) for img in images]
            targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

            optimizer.zero_grad()
            with torch.cuda.amp.autocast():
                loss_dict = model(images, targets)
                loss = sum(loss for loss in loss_dict.values())

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            total_train_loss += loss.item()

        # Validation (still in train mode to compute loss)
        model.train()
        total_val_loss = 0.0
        with torch.no_grad():
            for images, targets in val_loader:
                images = [img.to(device) for img in images]
                targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
                loss_dict = model(images, targets)
                loss = sum(loss for loss in loss_dict.values())
                total_val_loss += loss.item()

        scheduler.step()

        avg_train = total_train_loss / len(train_loader)
        avg_val = total_val_loss / len(val_loader)

        if avg_val < best_loss:
            best_loss = avg_val
            torch.save(model.state_dict(), os.path.join(output_dir, f'best_model_epoch{epoch+1}.pth'))

        print(f"[Epoch {epoch+1}/{epochs}] Train Loss: {avg_train:.4f} | Val Loss: {avg_val:.4f} | Time: {time.time()-start:.1f}s")

    torch.save(model.state_dict(), os.path.join(output_dir, 'final_model.pth'))
    print("✅ Training complete. Final model saved.")

# %%
train_model(
    train_dir='output/train',
    val_dir='output/val',
    num_classes=7,
    ann_filename='annotations.json',
    epochs=100,
    output_dir='results'
)
# Out:
# 🚀 Using device: cuda
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /home/manulab/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:01<00:00, 97.4MB/s]
# /tmp/ipykernel_37676/1126677313.py:101: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# /tmp/ipykernel_37676/1126677313.py:115: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [Epoch 1/100] Train Loss: 21.8814 | Val Loss: 20.2698 | Time: 13.9s
# [Epoch 2/100] Train Loss: 19.0735 | Val Loss: 17.8820 | Time: 14.1s
# [Epoch 3/100] Train Loss: 18.8169 | Val Loss: 18.5443 | Time: 13.5s
# [Epoch 4/100] Train Loss: 17.5078 | Val Loss: 15.7595 | Time: 13.9s
# [Epoch 5/100] Train Loss: 16.9489 | Val Loss: 14.4465 | Time: 13.9s
# [Epoch 6/100] Train Loss: 16.6482 | Val Loss: 15.4908 | Time: 13.6s
# [Epoch 7/100] Train Loss: 17.0645 | Val Loss: 16.4299 | Time: 13.6s
# [Epoch 8/100] Train Loss: 16.3644 | Val Loss: 13.9516 | Time: 13.6s
# [Epoch 9/100] Train Loss: 16.0825 | Val Loss: 14.5624 | Time: 13.6s
# [Epoch 10/100] Train Loss: 17.0938 | Val Loss: 13.6268 | Time: 13.8s
# [Epoch 11/100] Train Loss: 15.5162 | Val Loss: 15.2470 | Time: 13.4s
# [Epoch 12/100] Train Loss: 15.3977 | Val Loss: 14.0669 | Time: 13.7s
# [Epoch 13/100] Train Loss: 15.1293 | Val Loss: 14.7326 | Time: 13.7s
# [Epoch 14/100] Train Loss: 15.1056 | Val Loss: 13.8274 | Time: 13.5s
# [Epoch 15/100] Train Loss: 15.0251 | Val Loss: 13.7904 | Time: 13.5s
# [Epoch 16/100] Train Loss: 18.6033 | Val Loss: 14.7571 | Time: 13.5s
# [Epoch 17/100] Train Loss: 16.3041 | Val Loss: 15.6225 | Time: 13.4s
# [Epoch 18/100] Train Loss: 16.4450 | Val Loss: 17.7754 | Time: 13.5s
# [Epoch 19/100] Train Loss: 15.9199 | Val Loss: 14.4696 | Time: 13.7s
# [Epoch 20/100] Train Loss: 17.3119 | Val Loss: 15.1493 | Time: 13.2s
# [Epoch 21/100] Train Loss: 17.1927 | Val Loss: 14.5791 | Time: 13.5s
# [Epoch 22/100] Train Loss: 15.8184 | Val Loss: 15.2541 | Time: 13.4s
# [Epoch 23/100] Train Loss: 17.5607 | Val Loss: 21.7322 | Time: 13.5s
# [Epoch 24/100] Train Loss: 16.8710 | Val Loss: 14.4888 | Time: 13.4s
# [Epoch 25/100] Train Loss: 15.8055 | Val Loss: 15.2085 | Time: 13.5s
# [Epoch 26/100] Train Loss: 15.9349 | Val Loss: 13.9491 | Time: 13.4s
# [Epoch 27/100] Train Loss: 16.2006 | Val Loss: 14.7238 | Time: 13.5s
# [Epoch 28/100] Train Loss: 16.2320 | Val Loss: 13.0916 | Time: 14.1s
# [Epoch 29/100] Train Loss: 15.4294 | Val Loss: 15.3493 | Time: 13.3s
# [Epoch 30/100] Train Loss: 16.0807 | Val Loss: 13.1408 | Time: 13.4s
# [Epoch 31/100] Train Loss: 15.3919 | Val Loss: 14.0007 | Time: 13.7s
# [Epoch 32/100] Train Loss: 15.7060 | Val Loss: 14.1451 | Time: 13.4s
# [Epoch 33/100] Train Loss: 15.6419 | Val Loss: 13.8861 | Time: 13.6s
# [Epoch 34/100] Train Loss: 15.6516 | Val Loss: 14.4687 | Time: 13.2s
# [Epoch 35/100] Train Loss: 15.1907 | Val Loss: 13.7748 | Time: 13.8s
# [Epoch 36/100] Train Loss: 15.1550 | Val Loss: 13.7000 | Time: 13.7s
# [Epoch 37/100] Train Loss: 15.3503 | Val Loss: 14.6062 | Time: 13.7s
# [Epoch 38/100] Train Loss: 15.4964 | Val Loss: 13.8498 | Time: 13.5s
# [Epoch 39/100] Train Loss: 15.2372 | Val Loss: 14.3203 | Time: 13.3s
# [Epoch 40/100] Train Loss: 15.1455 | Val Loss: 13.8328 | Time: 13.2s
# [Epoch 41/100] Train Loss: 15.4014 | Val Loss: 14.1721 | Time: 14.0s
# [Epoch 42/100] Train Loss: 15.1410 | Val Loss: 13.8161 | Time: 13.7s
# [Epoch 43/100] Train Loss: 14.9167 | Val Loss: 14.0540 | Time: 13.6s
# [Epoch 44/100] Train Loss: 15.1047 | Val Loss: 13.8117 | Time: 13.5s
# [Epoch 45/100] Train Loss: 14.9465 | Val Loss: 13.8672 | Time: 13.5s
# [Epoch 46/100] Train Loss: 15.5915 | Val Loss: 13.7394 | Time: 13.3s
# [Epoch 47/100] Train Loss: 16.0720 | Val Loss: 14.4162 | Time: 13.5s
# [Epoch 48/100] Train Loss: 15.7179 | Val Loss: 14.5444 | Time: 13.6s
# [Epoch 49/100] Train Loss: 15.5349 | Val Loss: 14.4587 | Time: 13.4s
# [Epoch 50/100] Train Loss: 15.3520 | Val Loss: 13.2392 | Time: 13.4s
# [Epoch 51/100] Train Loss: 15.4119 | Val Loss: 13.9203 | Time: 13.4s
# [Epoch 52/100] Train Loss: 15.6583 | Val Loss: 13.2374 | Time: 13.5s
# [Epoch 53/100] Train Loss: 15.7107 | Val Loss: 13.9644 | Time: 13.5s
# [Epoch 54/100] Train Loss: 15.4924 | Val Loss: 13.5304 | Time: 13.7s
# [Epoch 55/100] Train Loss: 15.4576 | Val Loss: 13.4359 | Time: 13.4s
# [Epoch 56/100] Train Loss: 15.1910 | Val Loss: 14.1765 | Time: 13.5s
# [Epoch 57/100] Train Loss: 15.4917 | Val Loss: 13.5881 | Time: 13.5s
# [Epoch 58/100] Train Loss: 15.5399 | Val Loss: 12.9757 | Time: 14.0s
# [Epoch 59/100] Train Loss: 15.0129 | Val Loss: 13.9512 | Time: 13.3s
# [Epoch 60/100] Train Loss: 15.1976 | Val Loss: 13.5392 | Time: 13.6s
# [Epoch 61/100] Train Loss: 15.2991 | Val Loss: 13.7578 | Time: 13.6s
# [Epoch 62/100] Train Loss: 15.1335 | Val Loss: 13.1573 | Time: 13.7s
# [Epoch 63/100] Train Loss: 15.6741 | Val Loss: 13.5179 | Time: 13.5s
# [Epoch 64/100] Train Loss: 15.5259 | Val Loss: 13.1564 | Time: 13.4s
# [Epoch 65/100] Train Loss: 15.5427 | Val Loss: 13.7296 | Time: 13.5s
# [Epoch 66/100] Train Loss: 15.0685 | Val Loss: 13.4153 | Time: 13.6s
# [Epoch 67/100] Train Loss: 15.5041 | Val Loss: 13.6094 | Time: 13.7s
# [Epoch 68/100] Train Loss: 15.4552 | Val Loss: 12.8702 | Time: 13.9s
# [Epoch 69/100] Train Loss: 15.1465 | Val Loss: 13.5033 | Time: 13.5s
# [Epoch 70/100] Train Loss: 15.3816 | Val Loss: 13.2593 | Time: 13.3s
# [Epoch 71/100] Train Loss: 14.9753 | Val Loss: 13.2488 | Time: 13.5s
# [Epoch 72/100] Train Loss: 15.1200 | Val Loss: 13.5263 | Time: 13.5s
# [Epoch 73/100] Train Loss: 15.5252 | Val Loss: 13.8591 | Time: 13.6s
# [Epoch 74/100] Train Loss: 15.2083 | Val Loss: 13.4932 | Time: 13.5s
# [Epoch 75/100] Train Loss: 15.5070 | Val Loss: 13.4771 | Time: 13.4s
# [Epoch 76/100] Train Loss: 15.2803 | Val Loss: 13.3325 | Time: 13.3s
# [Epoch 77/100] Train Loss: 15.0655 | Val Loss: 13.4241 | Time: 13.6s
# [Epoch 78/100] Train Loss: 15.2624 | Val Loss: 13.2179 | Time: 13.4s
# [Epoch 79/100] Train Loss: 15.0765 | Val Loss: 14.3032 | Time: 13.7s
# [Epoch 80/100] Train Loss: 15.3812 | Val Loss: 13.5629 | Time: 13.2s
# [Epoch 81/100] Train Loss: 15.1546 | Val Loss: 13.1799 | Time: 13.8s
# [Epoch 82/100] Train Loss: 14.9105 | Val Loss: 13.6383 | Time: 13.5s
# [Epoch 83/100] Train Loss: 14.6908 | Val Loss: 13.5315 | Time: 13.5s
# [Epoch 84/100] Train Loss: 15.3424 | Val Loss: 13.0045 | Time: 13.5s
# [Epoch 85/100] Train Loss: 14.8351 | Val Loss: 13.6555 | Time: 13.6s
# [Epoch 86/100] Train Loss: 15.1359 | Val Loss: 13.7409 | Time: 13.7s
# [Epoch 87/100] Train Loss: 15.2761 | Val Loss: 14.0838 | Time: 13.6s
# [Epoch 88/100] Train Loss: 15.0302 | Val Loss: 13.7921 | Time: 13.8s
# [Epoch 89/100] Train Loss: 15.3283 | Val Loss: 13.8423 | Time: 13.7s
# [Epoch 90/100] Train Loss: 15.0607 | Val Loss: 13.7806 | Time: 13.3s
# [Epoch 91/100] Train Loss: 15.0975 | Val Loss: 13.4511 | Time: 13.6s
# [Epoch 92/100] Train Loss: 15.0332 | Val Loss: 13.5385 | Time: 14.0s
# [Epoch 93/100] Train Loss: 14.9760 | Val Loss: 13.5877 | Time: 13.6s
# [Epoch 94/100] Train Loss: 14.9671 | Val Loss: 13.5486 | Time: 13.9s
# [Epoch 95/100] Train Loss: 14.9030 | Val Loss: 13.8642 | Time: 13.3s
# [Epoch 96/100] Train Loss: 14.7701 | Val Loss: 13.6905 | Time: 13.4s
# [Epoch 97/100] Train Loss: 14.7378 | Val Loss: 13.6405 | Time: 13.8s
# [Epoch 98/100] Train Loss: 14.6453 | Val Loss: 13.8219 | Time: 13.6s
# [Epoch 99/100] Train Loss: 14.7108 | Val Loss: 13.3911 | Time: 13.4s
# [Epoch 100/100] Train Loss: 14.4759 | Val Loss: 13.7637 | Time: 13.3s
# ✅ Training complete. Final model saved.
